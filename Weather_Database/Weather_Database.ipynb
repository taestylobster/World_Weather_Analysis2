# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
coordinates = list(lat_lngs)
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + city.replace(" ","+")

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
  
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | angostura
# Processing Record 3 of Set 1 | tabou
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | sitka
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | san quintin
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | alice springs
# Processing Record 15 of Set 1 | kupang
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | riyadh
# Processing Record 18 of Set 1 | batagay
# Processing Record 19 of Set 1 | vestmannaeyjar
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | lazaro cardenas
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | labuhan
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | chulman
# Processing Record 28 of Set 1 | ponta delgada
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | auki
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | coquimbo
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | san andres
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | cabinda
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | kamyshlov
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | grand gaube
# Processing Record 46 of Set 1 | shanghai
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | tura
# Processing Record 49 of Set 1 | aulla
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | ulladulla
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | kafanchan
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | jaque
# Processing Record 10 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 2 | inverness
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | labuan
# Processing Record 15 of Set 2 | shar
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | ketchikan
# Processing Record 21 of Set 2 | port-gentil
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | acarau
# Processing Record 24 of Set 2 | chom bung
# City not found. Skipping...
# Processing Record 25 of Set 2 | bafq
# Processing Record 26 of Set 2 | sibolga
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | kodinsk
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | maicao
# Processing Record 38 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | estelle
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | semey
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | agua verde
# Processing Record 47 of Set 2 | ozinki
# Processing Record 48 of Set 2 | catia la mar
# Processing Record 49 of Set 2 | formosa
# Processing Record 50 of Set 2 | burica
# City not found. Skipping...
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | riverton
# Processing Record 4 of Set 3 | wisla
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | nueve de julio
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | cam ranh
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | altay
# Processing Record 12 of Set 3 | la libertad
# Processing Record 13 of Set 3 | santiago de chuco
# Processing Record 14 of Set 3 | sorland
# Processing Record 15 of Set 3 | saint-michel-sur-orge
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | agdas
# Processing Record 18 of Set 3 | abay
# Processing Record 19 of Set 3 | kulhudhuffushi
# Processing Record 20 of Set 3 | karpogory
# Processing Record 21 of Set 3 | moerai
# Processing Record 22 of Set 3 | dwarka
# Processing Record 23 of Set 3 | svetlaya
# Processing Record 24 of Set 3 | nemea
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | belyy yar
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | wanning
# Processing Record 30 of Set 3 | banda aceh
# Processing Record 31 of Set 3 | qaqortoq
# Processing Record 32 of Set 3 | xique-xique
# Processing Record 33 of Set 3 | ivanava
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | vanimo
# Processing Record 36 of Set 3 | sur
# Processing Record 37 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 3 | tual
# Processing Record 39 of Set 3 | champerico
# Processing Record 40 of Set 3 | rawson
# Processing Record 41 of Set 3 | aksay
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | fare
# Processing Record 44 of Set 3 | naze
# Processing Record 45 of Set 3 | gallup
# Processing Record 46 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 3 | macusani
# Processing Record 48 of Set 3 | cape town
# Processing Record 49 of Set 3 | foz
# Processing Record 50 of Set 3 | atar
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | celestun
# Processing Record 3 of Set 4 | sovetskaya gavan
# Processing Record 4 of Set 4 | san joaquin
# Processing Record 5 of Set 4 | dryden
# Processing Record 6 of Set 4 | tautira
# Processing Record 7 of Set 4 | port lincoln
# Processing Record 8 of Set 4 | coria
# Processing Record 9 of Set 4 | evensk
# Processing Record 10 of Set 4 | ann arbor
# Processing Record 11 of Set 4 | luanda
# Processing Record 12 of Set 4 | coolum beach
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | sumbe
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | ternate
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | raymondville
# Processing Record 20 of Set 4 | chimore
# Processing Record 21 of Set 4 | bangassou
# Processing Record 22 of Set 4 | dubbo
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | marawi
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | rabo de peixe
# Processing Record 27 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 4 | ahuimanu
# Processing Record 29 of Set 4 | sterling
# Processing Record 30 of Set 4 | parrsboro
# Processing Record 31 of Set 4 | pombia
# Processing Record 32 of Set 4 | yarmouth
# Processing Record 33 of Set 4 | port hardy
# Processing Record 34 of Set 4 | hermanus
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | washougal
# Processing Record 37 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 4 | xuddur
# Processing Record 39 of Set 4 | garowe
# Processing Record 40 of Set 4 | brae
# Processing Record 41 of Set 4 | yamethin
# Processing Record 42 of Set 4 | kamenka
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | zurrieq
# Processing Record 46 of Set 4 | alyangula
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | itarantim
# Processing Record 49 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | noumea
# Processing Record 2 of Set 5 | blagoyevo
# Processing Record 3 of Set 5 | karratha
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | hasaki
# Processing Record 6 of Set 5 | yamada
# Processing Record 7 of Set 5 | kilosa
# Processing Record 8 of Set 5 | bilibino
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | itarema
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | dalbandin
# Processing Record 13 of Set 5 | half moon bay
# Processing Record 14 of Set 5 | murgab
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | khandyga
# Processing Record 18 of Set 5 | tortoli
# Processing Record 19 of Set 5 | yegros
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | dinajpur
# Processing Record 22 of Set 5 | beloha
# Processing Record 23 of Set 5 | barra
# Processing Record 24 of Set 5 | bethel
# Processing Record 25 of Set 5 | salamiyah
# Processing Record 26 of Set 5 | ulaangom
# Processing Record 27 of Set 5 | villa maria
# Processing Record 28 of Set 5 | zhigansk
# Processing Record 29 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | ribeirao bonito
# Processing Record 31 of Set 5 | comodoro rivadavia
# Processing Record 32 of Set 5 | adeje
# Processing Record 33 of Set 5 | merauke
# Processing Record 34 of Set 5 | caravelas
# Processing Record 35 of Set 5 | kasama
# Processing Record 36 of Set 5 | constantine
# Processing Record 37 of Set 5 | katherine
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | nahrin
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | hvolsvollur
# Processing Record 43 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | khoni
# Processing Record 46 of Set 5 | novouzensk
# Processing Record 47 of Set 5 | avera
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | velsk
# Processing Record 50 of Set 5 | pine bluff
# Processing Record 1 of Set 6 | boundiali
# Processing Record 2 of Set 6 | hailar
# Processing Record 3 of Set 6 | melfi
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | tomohon
# Processing Record 8 of Set 6 | esperance
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | aykhal
# Processing Record 16 of Set 6 | atbasar
# Processing Record 17 of Set 6 | puerto madryn
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | harper
# Processing Record 20 of Set 6 | pisco
# Processing Record 21 of Set 6 | hobart
# Processing Record 22 of Set 6 | ambalavao
# Processing Record 23 of Set 6 | porto novo
# Processing Record 24 of Set 6 | dukat
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | sao felix do xingu
# Processing Record 28 of Set 6 | marion
# Processing Record 29 of Set 6 | gali
# Processing Record 30 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 6 | salima
# Processing Record 32 of Set 6 | turayf
# Processing Record 33 of Set 6 | narsaq
# Processing Record 34 of Set 6 | yerbogachen
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | poum
# Processing Record 39 of Set 6 | tombouctou
# Processing Record 40 of Set 6 | aksu
# Processing Record 41 of Set 6 | kahului
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | san fernando
# Processing Record 44 of Set 6 | kanniyakumari
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | nabire
# Processing Record 47 of Set 6 | akot
# Processing Record 48 of Set 6 | cherskiy
# Processing Record 49 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 6 | namibe
# Processing Record 1 of Set 7 | constitucion
# Processing Record 2 of Set 7 | sambava
# Processing Record 3 of Set 7 | cambrils
# Processing Record 4 of Set 7 | bhawanipatna
# Processing Record 5 of Set 7 | korfovskiy
# Processing Record 6 of Set 7 | luebo
# Processing Record 7 of Set 7 | virginia beach
# Processing Record 8 of Set 7 | dembi dolo
# Processing Record 9 of Set 7 | landeck
# Processing Record 10 of Set 7 | taber
# Processing Record 11 of Set 7 | izhmorskiy
# Processing Record 12 of Set 7 | guiyang
# Processing Record 13 of Set 7 | jackson
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | kavaratti
# Processing Record 16 of Set 7 | hoquiam
# Processing Record 17 of Set 7 | filingue
# Processing Record 18 of Set 7 | ibra
# Processing Record 19 of Set 7 | kosice
# Processing Record 20 of Set 7 | tolon
# Processing Record 21 of Set 7 | maragogi
# Processing Record 22 of Set 7 | mareeba
# Processing Record 23 of Set 7 | mecca
# Processing Record 24 of Set 7 | krasnoselkup
# Processing Record 25 of Set 7 | apartado
# Processing Record 26 of Set 7 | buzmeyin
# Processing Record 27 of Set 7 | strezhevoy
# Processing Record 28 of Set 7 | eyl
# Processing Record 29 of Set 7 | novikovo
# Processing Record 30 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 7 | trairi
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | staryy nadym
# Processing Record 34 of Set 7 | abhar
# Processing Record 35 of Set 7 | saiha
# Processing Record 36 of Set 7 | provideniya
# Processing Record 37 of Set 7 | shiyan
# Processing Record 38 of Set 7 | guerrero negro
# Processing Record 39 of Set 7 | batemans bay
# Processing Record 40 of Set 7 | lloydminster
# Processing Record 41 of Set 7 | kuala terengganu
# Processing Record 42 of Set 7 | hurricane
# Processing Record 43 of Set 7 | tuy hoa
# Processing Record 44 of Set 7 | mazagao
# Processing Record 45 of Set 7 | calabozo
# Processing Record 46 of Set 7 | naliya
# Processing Record 47 of Set 7 | edd
# Processing Record 48 of Set 7 | klungkung
# Processing Record 49 of Set 7 | lompoc
# Processing Record 50 of Set 7 | khovu-aksy
# Processing Record 1 of Set 8 | tarakan
# Processing Record 2 of Set 8 | waingapu
# Processing Record 3 of Set 8 | changying
# Processing Record 4 of Set 8 | fairbanks
# Processing Record 5 of Set 8 | san pedro
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | kudahuvadhoo
# Processing Record 10 of Set 8 | mersing
# Processing Record 11 of Set 8 | saint-leu
# Processing Record 12 of Set 8 | ucluelet
# Processing Record 13 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 8 | pampa
# Processing Record 15 of Set 8 | akoupe
# Processing Record 16 of Set 8 | manaus
# Processing Record 17 of Set 8 | adrar
# Processing Record 18 of Set 8 | yakeshi
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | mackenzie
# Processing Record 21 of Set 8 | alto araguaia
# Processing Record 22 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 8 | makung
# City not found. Skipping...
# Processing Record 24 of Set 8 | hay river
# Processing Record 25 of Set 8 | puri
# Processing Record 26 of Set 8 | mount gambier
# Processing Record 27 of Set 8 | erdenet
# Processing Record 28 of Set 8 | ambulu
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | grindavik
# Processing Record 31 of Set 8 | raudeberg
# Processing Record 32 of Set 8 | bantry
# Processing Record 33 of Set 8 | pimenta bueno
# Processing Record 34 of Set 8 | srisailam
# Processing Record 35 of Set 8 | dubai
# Processing Record 36 of Set 8 | quechultenango
# Processing Record 37 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 8 | sola
# Processing Record 40 of Set 8 | mangrol
# Processing Record 41 of Set 8 | fredensborg
# Processing Record 42 of Set 8 | botou
# Processing Record 43 of Set 8 | nyurba
# Processing Record 44 of Set 8 | otradnoye
# Processing Record 45 of Set 8 | pangody
# Processing Record 46 of Set 8 | tasiilaq
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | foggia
# Processing Record 49 of Set 8 | camacha
# Processing Record 50 of Set 8 | yelahanka
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | lac du bonnet
# Processing Record 3 of Set 9 | killam
# Processing Record 4 of Set 9 | pangai
# Processing Record 5 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 9 | vila velha
# Processing Record 7 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 9 | alihe
# Processing Record 9 of Set 9 | port hueneme
# Processing Record 10 of Set 9 | ramnagar
# Processing Record 11 of Set 9 | kaeo
# Processing Record 12 of Set 9 | cassilandia
# Processing Record 13 of Set 9 | buala
# Processing Record 14 of Set 9 | wellington
# Processing Record 15 of Set 9 | tatishchevo
# Processing Record 16 of Set 9 | necochea
# Processing Record 17 of Set 9 | mogadishu
# Processing Record 18 of Set 9 | northam
# Processing Record 19 of Set 9 | yeppoon
# Processing Record 20 of Set 9 | nova olinda do norte
# Processing Record 21 of Set 9 | danbury
# Processing Record 22 of Set 9 | abalak
# Processing Record 23 of Set 9 | axim
# Processing Record 24 of Set 9 | pilar
# Processing Record 25 of Set 9 | guozhen
# Processing Record 26 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | jesup
# Processing Record 28 of Set 9 | kremenki
# Processing Record 29 of Set 9 | impfondo
# Processing Record 30 of Set 9 | westerland
# Processing Record 31 of Set 9 | harlingen
# Processing Record 32 of Set 9 | tezu
# Processing Record 33 of Set 9 | kwakoa
# Processing Record 34 of Set 9 | hailey
# Processing Record 35 of Set 9 | byron bay
# Processing Record 36 of Set 9 | mayo
# Processing Record 37 of Set 9 | abdulino
# Processing Record 38 of Set 9 | mandali
# Processing Record 39 of Set 9 | bathsheba
# Processing Record 40 of Set 9 | tadine
# Processing Record 41 of Set 9 | jintur
# Processing Record 42 of Set 9 | shimoda
# Processing Record 43 of Set 9 | olinda
# Processing Record 44 of Set 9 | vilhena
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | yar-sale
# Processing Record 47 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 9 | nouakchott
# Processing Record 49 of Set 9 | marondera
# Processing Record 50 of Set 9 | pazaric
# Processing Record 1 of Set 10 | kyabe
# Processing Record 2 of Set 10 | bosaso
# Processing Record 3 of Set 10 | tselina
# Processing Record 4 of Set 10 | quatre cocos
# Processing Record 5 of Set 10 | ulaanbaatar
# Processing Record 6 of Set 10 | booue
# Processing Record 7 of Set 10 | saint-francois
# Processing Record 8 of Set 10 | muros
# Processing Record 9 of Set 10 | cayenne
# Processing Record 10 of Set 10 | tiarei
# Processing Record 11 of Set 10 | lerwick
# Processing Record 12 of Set 10 | hibbing
# Processing Record 13 of Set 10 | la plaine
# Processing Record 14 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | buin
# Processing Record 17 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 10 | chakrata
# Processing Record 19 of Set 10 | yangambi
# Processing Record 20 of Set 10 | maneciu
# Processing Record 21 of Set 10 | suntar
# Processing Record 22 of Set 10 | votkinsk
# Processing Record 23 of Set 10 | bogale
# Processing Record 24 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 10 | yumen
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | montepuez
# Processing Record 28 of Set 10 | bloemfontein
# Processing Record 29 of Set 10 | dudinka
# Processing Record 30 of Set 10 | tromso
# Processing Record 31 of Set 10 | bogovarovo
# Processing Record 32 of Set 10 | ukiah
# Processing Record 33 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 10 | broome
# Processing Record 35 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 36 of Set 10 | deputatskiy
# Processing Record 37 of Set 10 | ouargaye
# Processing Record 38 of Set 10 | sheridan
# Processing Record 39 of Set 10 | barranca
# Processing Record 40 of Set 10 | todos santos
# Processing Record 41 of Set 10 | burnie
# Processing Record 42 of Set 10 | varhaug
# Processing Record 43 of Set 10 | bolu
# Processing Record 44 of Set 10 | morehead
# Processing Record 45 of Set 10 | cody
# Processing Record 46 of Set 10 | tahe
# Processing Record 47 of Set 10 | novyy urengoy
# Processing Record 48 of Set 10 | big bend
# Processing Record 49 of Set 10 | venezuela
# Processing Record 50 of Set 10 | kolondieba
# Processing Record 1 of Set 11 | pak chong
# Processing Record 2 of Set 11 | zaraza
# Processing Record 3 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 11 | birao
# Processing Record 5 of Set 11 | tecoanapa
# Processing Record 6 of Set 11 | panaba
# Processing Record 7 of Set 11 | troitsk
# Processing Record 8 of Set 11 | san rafael
# Processing Record 9 of Set 11 | sorong
# Processing Record 10 of Set 11 | ellisras
# Processing Record 11 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 11 | saquena
# Processing Record 13 of Set 11 | ozark
# Processing Record 14 of Set 11 | ordu
# Processing Record 15 of Set 11 | dzhebariki-khaya
# Processing Record 16 of Set 11 | yacuiba
# Processing Record 17 of Set 11 | tekeli
# Processing Record 18 of Set 11 | la uribe
# City not found. Skipping...
# Processing Record 19 of Set 11 | luderitz
# Processing Record 20 of Set 11 | buchanan
# Processing Record 21 of Set 11 | chara
# Processing Record 22 of Set 11 | kununurra
# Processing Record 23 of Set 11 | mouila
# Processing Record 24 of Set 11 | monte alegre
# Processing Record 25 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 26 of Set 11 | inta
# Processing Record 27 of Set 11 | kenai
# Processing Record 28 of Set 11 | zabid
# Processing Record 29 of Set 11 | oranjemund
# Processing Record 30 of Set 11 | cabatuan
# Processing Record 31 of Set 11 | swan hill
# Processing Record 32 of Set 11 | torrington
# Processing Record 33 of Set 11 | nome
# Processing Record 34 of Set 11 | pangnirtung
# Processing Record 35 of Set 11 | angoram
# Processing Record 36 of Set 11 | saldanha
# Processing Record 37 of Set 11 | coos bay
# Processing Record 38 of Set 11 | inongo
# Processing Record 39 of Set 11 | usinsk
# Processing Record 40 of Set 11 | hirara
# Processing Record 41 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 11 | hemsedal
# Processing Record 43 of Set 11 | la ronge
# Processing Record 44 of Set 11 | rio tercero
# Processing Record 45 of Set 11 | sao jose da coroa grande
# Processing Record 46 of Set 11 | salalah
# Processing Record 47 of Set 11 | berlevag
# Processing Record 48 of Set 11 | augusto correa
# Processing Record 49 of Set 11 | formosa do rio preto
# Processing Record 50 of Set 11 | ugoofaaru
# Processing Record 1 of Set 12 | port hedland
# Processing Record 2 of Set 12 | la asuncion
# Processing Record 3 of Set 12 | marsh harbour
# Processing Record 4 of Set 12 | hastings
# Processing Record 5 of Set 12 | port augusta
# Processing Record 6 of Set 12 | pringsewu
# Processing Record 7 of Set 12 | shubarkuduk
# Processing Record 8 of Set 12 | daru
# Processing Record 9 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 12 | kismayo
# Processing Record 11 of Set 12 | lincoln
# Processing Record 12 of Set 12 | norden
# Processing Record 13 of Set 12 | srednekolymsk
# Processing Record 14 of Set 12 | beringovskiy
# Processing Record 15 of Set 12 | pyaozerskiy
# Processing Record 16 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 12 | izumo
# Processing Record 18 of Set 12 | lasa
# Processing Record 19 of Set 12 | saint-michel-des-saints
# Processing Record 20 of Set 12 | ust-kuyga
# Processing Record 21 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 22 of Set 12 | solnechnyy
# Processing Record 23 of Set 12 | san ignacio
# Processing Record 24 of Set 12 | port blair
# Processing Record 25 of Set 12 | aviles
# Processing Record 26 of Set 12 | ca mau
# Processing Record 27 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 28 of Set 12 | nazas
# Processing Record 29 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 12 | albacete
# Processing Record 31 of Set 12 | tianpeng
# Processing Record 32 of Set 12 | airai
# Processing Record 33 of Set 12 | medea
# Processing Record 34 of Set 12 | araouane
# Processing Record 35 of Set 12 | abu kamal
# Processing Record 36 of Set 12 | bronnoysund
# Processing Record 37 of Set 12 | gat
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | malinyi
# Processing Record 40 of Set 12 | lobao
# Processing Record 41 of Set 12 | halifax
# Processing Record 42 of Set 12 | aquidauana
# Processing Record 43 of Set 12 | kenora
# Processing Record 44 of Set 12 | sisimiut
# Processing Record 45 of Set 12 | bambanglipuro
# Processing Record 46 of Set 12 | rocha
# Processing Record 47 of Set 12 | kaduqli
# Processing Record 48 of Set 12 | portland
# Processing Record 49 of Set 12 | makhinjauri
# Processing Record 50 of Set 12 | quang ngai
# Processing Record 1 of Set 13 | isla vista
# Processing Record 2 of Set 13 | roald
# Processing Record 3 of Set 13 | teguise
# Processing Record 4 of Set 13 | seoul
# Processing Record 5 of Set 13 | springhill
# Processing Record 6 of Set 13 | anchorage
# Processing Record 7 of Set 13 | erzin
# Processing Record 8 of Set 13 | dalvik
# Processing Record 9 of Set 13 | belaya gora
# Processing Record 10 of Set 13 | palembang
# Processing Record 11 of Set 13 | bull savanna
# Processing Record 12 of Set 13 | muscatine
# Processing Record 13 of Set 13 | arona
# Processing Record 14 of Set 13 | stara vyzhivka
# Processing Record 15 of Set 13 | tricase
# Processing Record 16 of Set 13 | jucurutu
# Processing Record 17 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 13 | altagracia de orituco
# Processing Record 19 of Set 13 | rio blanco
# Processing Record 20 of Set 13 | huescar
# Processing Record 21 of Set 13 | gondar
# Processing Record 22 of Set 13 | caraquet
# Processing Record 23 of Set 13 | saint marys
# Processing Record 24 of Set 13 | fujin
# Processing Record 25 of Set 13 | isangel
# Processing Record 26 of Set 13 | athabasca
# Processing Record 27 of Set 13 | anadyr
# Processing Record 28 of Set 13 | port antonio
# Processing Record 29 of Set 13 | kirakira
# Processing Record 30 of Set 13 | acari
# Processing Record 31 of Set 13 | huarmey
# Processing Record 32 of Set 13 | jiayuguan
# Processing Record 33 of Set 13 | banning
# Processing Record 34 of Set 13 | abbeville
# Processing Record 35 of Set 13 | chipinge
# Processing Record 36 of Set 13 | sao raimundo das mangabeiras
# Processing Record 37 of Set 13 | robertsport
# Processing Record 38 of Set 13 | shabo
# Processing Record 39 of Set 13 | potosi
# Processing Record 40 of Set 13 | assiniboia
# Processing Record 41 of Set 13 | amga
# Processing Record 42 of Set 13 | kokrajhar
# Processing Record 43 of Set 13 | urumqi
# Processing Record 44 of Set 13 | pauri
# Processing Record 45 of Set 13 | mansa
# Processing Record 46 of Set 13 | bandar-e lengeh
# Processing Record 47 of Set 13 | lagoa
# Processing Record 48 of Set 13 | yanaul
# Processing Record 49 of Set 13 | puga
# Processing Record 50 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 14 | takoradi
# Processing Record 2 of Set 14 | chernyshevskiy
# Processing Record 3 of Set 14 | hervey bay
# Processing Record 4 of Set 14 | meulaboh
# Processing Record 5 of Set 14 | itaituba
# Processing Record 6 of Set 14 | doka
# Processing Record 7 of Set 14 | keetmanshoop
# Processing Record 8 of Set 14 | aloleng
# Processing Record 9 of Set 14 | krumovgrad
# Processing Record 10 of Set 14 | ziro
# Processing Record 11 of Set 14 | vila franca do campo
# Processing Record 12 of Set 14 | bischofshofen
# Processing Record 13 of Set 14 | sonoita
# Processing Record 14 of Set 14 | olafsvik
# Processing Record 15 of Set 14 | abu dhabi
# Processing Record 16 of Set 14 | toma
# Processing Record 17 of Set 14 | brokopondo
# Processing Record 18 of Set 14 | hare bay
# Processing Record 19 of Set 14 | kalaleh
# Processing Record 20 of Set 14 | yichun
# Processing Record 21 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 22 of Set 14 | carballo
# Processing Record 23 of Set 14 | honiara
# Processing Record 24 of Set 14 | santa fe
# Processing Record 25 of Set 14 | shkotovo-26
# City not found. Skipping...
# Processing Record 26 of Set 14 | lugovoy
# Processing Record 27 of Set 14 | leningradskiy
# Processing Record 28 of Set 14 | boo
# Processing Record 29 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 30 of Set 14 | nhulunbuy
# Processing Record 31 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 14 | kalmunai
# Processing Record 33 of Set 14 | ransang
# Processing Record 34 of Set 14 | tazovskiy
# Processing Record 35 of Set 14 | sioni
# Processing Record 36 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 14 | jacareacanga
# Processing Record 38 of Set 14 | rosarito
# Processing Record 39 of Set 14 | rio grande
# Processing Record 40 of Set 14 | sabya
# Processing Record 41 of Set 14 | bria
# Processing Record 42 of Set 14 | elk city
# Processing Record 43 of Set 14 | presov
# Processing Record 44 of Set 14 | vila
# Processing Record 45 of Set 14 | ongandjera
# Processing Record 46 of Set 14 | sarahan
# Processing Record 47 of Set 14 | wuwei
# Processing Record 48 of Set 14 | turki
# Processing Record 49 of Set 14 | verkhnevilyuysk
# Processing Record 50 of Set 14 | ewa beach
# Processing Record 1 of Set 15 | bandarbeyla
# Processing Record 2 of Set 15 | daultala
# Processing Record 3 of Set 15 | bjornevatn
# Processing Record 4 of Set 15 | vetralla
# Processing Record 5 of Set 15 | fort nelson
# Processing Record 6 of Set 15 | san patricio
# Processing Record 7 of Set 15 | tsabong
# Processing Record 8 of Set 15 | sucre
# Processing Record 9 of Set 15 | porto torres
# Processing Record 10 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 11 of Set 15 | thanh hoa
# Processing Record 12 of Set 15 | nikel
# Processing Record 13 of Set 15 | nioro
# Processing Record 14 of Set 15 | iracoubo
# Processing Record 15 of Set 15 | pompeu
# Processing Record 16 of Set 15 | dunda
# Processing Record 17 of Set 15 | korampallam
# Processing Record 18 of Set 15 | nemuro
# Processing Record 19 of Set 15 | xudat
# Processing Record 20 of Set 15 | te anau
# Processing Record 21 of Set 15 | atambua
# Processing Record 22 of Set 15 | forio
# Processing Record 23 of Set 15 | dartford
# Processing Record 24 of Set 15 | shimanovsk
# Processing Record 25 of Set 15 | keti bandar
# Processing Record 26 of Set 15 | hargeysa
# Processing Record 27 of Set 15 | puerto quijarro
# Processing Record 28 of Set 15 | satuk
# Processing Record 29 of Set 15 | sechura
# Processing Record 30 of Set 15 | crawley
# Processing Record 31 of Set 15 | mormugao
# Processing Record 32 of Set 15 | padang
# Processing Record 33 of Set 15 | linapacan
# City not found. Skipping...
# Processing Record 34 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 35 of Set 15 | george
# Processing Record 36 of Set 15 | nadvoitsy
# Processing Record 37 of Set 15 | eureka
# Processing Record 38 of Set 15 | dunedin
# Processing Record 39 of Set 15 | lhokseumawe
# Processing Record 40 of Set 15 | bontang
# Processing Record 41 of Set 15 | kankaanpaa
# Processing Record 42 of Set 15 | inuvik
# Processing Record 43 of Set 15 | atasu
# Processing Record 44 of Set 15 | sakakah
# Processing Record 45 of Set 15 | zalari
# Processing Record 46 of Set 15 | mehamn
# Processing Record 47 of Set 15 | korla
# Processing Record 48 of Set 15 | kassala
# Processing Record 49 of Set 15 | palmer
# Processing Record 50 of Set 15 | shelburne
# Processing Record 1 of Set 16 | saint-denis
# Processing Record 2 of Set 16 | puro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini -21.2000 -175.2000     71.76       100          90
# 1        Angostura  25.3667 -108.1833     96.01        42           6
# 2            Tabou   4.4230   -7.3528     78.03        89         100
# 3     Punta Arenas -53.1500  -70.9167     53.71        35          20
# 4            Sitka  57.0531 -135.3300     46.29        87          75
# 5  Arraial Do Cabo -22.9661  -42.0278     66.16        94          90
# 6           Avarua -21.2078 -159.7750     75.25        78         100
# 7   Saint-Philippe -21.3585   55.7679     72.95        88          11
# 8   Ribeira Grande  38.5167  -28.7000     72.00        94          40
# 9      San Quintin  30.4833 -115.9500     73.02        54           0
#
#    Wind Speed Current Description Country                 Date
# 0        2.30     overcast clouds      TO  2021-10-10 19:47:11
# 1        9.13           clear sky      MX  2021-10-10 19:47:11
# 2        9.19          light rain      CI  2021-10-10 19:47:12
# 3       34.52          few clouds      CL  2021-10-10 19:46:22
# 4        5.75          light rain      US  2021-10-10 19:47:12
# 5       12.66                mist      BR  2021-10-10 19:47:12
# 6        4.61     overcast clouds      CK  2021-10-10 19:42:32
# 7        7.61          few clouds      RE  2021-10-10 19:47:13
# 8       14.97    scattered clouds      PT  2021-10-10 19:47:13
# 9        9.89           clear sky      MX  2021-10-10 19:47:13

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
